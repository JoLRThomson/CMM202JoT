# %% [markdown]
# <a href="https://colab.research.google.com/github/JoLRThomson/CMM202JoT/blob/main/EV_JoT_24_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **CMM202 - COURSEWORK PART 2**

# %% [markdown]
# **Submitted By:**
#
# **Joanne Thomson** (2116623)
#
# **Mercy Ogunsanwo** (2112865)
#
# **Poonam Soni** (2110506)

# %% [markdown]
# #                                            **Electric Vehicle Analysis**

# %% [markdown]
# ![evc.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # **DATA SELECTION**

# %% [markdown]
# **Introduction**

# %% [markdown]
# The concept of EV was not popular when Tesla released its first electric car in 2008. But today, the customer perception has changed and every major vehicle manufacturer has now entered into this market. Despite the Covid 19 pandemic, EV sales surged in the later half of [2020](https://www.iea.org/reports/global-ev-outlook-2021/policies-to-promote-electric-vehicle-deployment) with countries around the world offering [subsidies and incentives](https://www.weforum.org/agenda/2021/06/electric-vehicles-financial-incentives/) on purchase of these vehicles. Governments around the globe are already talking about banning sale of petrol and diesel cars, which will further drive EV sales. As per a report from [Mckinsey](https://www.mckinsey.com/industries/automotive-and-assembly/our-insights/why-the-automotive-future-is-electric), Europe will be a global leader in EV sales with 60 percent sales by 2030.  Apart from being stylish and appealing, they are better for the [environment](https://www.edfenergy.com/for-home/energywise/electric-cars-and-environment),  and emit fewer greenhouse gases and air pollutants than petrol or diesel cars.

# %% [markdown]
# The reason we have chosen this data as a basis for our project is because due to rising prices of fuel, people are looking at other options. Electric vehicles have emerged as a cost effective way for transportation. The market for EV is still new but as more and more models are being launched, people have started exploring the option to switch from fuel based cars to electric cars. As the features of an EV are different as compared to fuel based cars, it is essential to choose carefully which EV to buy. Earlier, the decision was based mostly on the car's range. But today, with a lot of options available, it is  important to consider all the features and see which one fits our lifestyle best.

# %% [markdown]
# Goal of this project is to analyse the important features of EVs which can provide a basis for a person who wants to buy an electric car. The questions that we will try to answer are:
#
# **FEASIBILITY: WHERE AND HOW TO CHARGE THE VEHICLE?**
#
# **TRAVEL NEEDS: CAR’S OPERATING RANGE**
#
# **COMFORT: DOES THE VEHICLE MEET ME AND MY FAMILY NEEDS?**
#
# **DOES IT FIT THE BUDGET**
#
# **EFFICIENCY AND PERFORMANCE**

# %% [markdown]
# **Datasets**

# %% [markdown]
# There are three datasets used for this project.
#
# EV_data: Data has been taken from [Kaggle](https://www.kaggle.com/datasets/geoffnel/evs-one-electric-vehicle-dataset?select=ElectricCarData_Norm.csv).
#
# FEV_data: Data has been taken from [Mendeley Data](https://data.mendeley.com/datasets/tb9yrptydn/2)
#
# National_Charge_Point Registry: Data has been taken from  [GOV.UK](https://www.gov.uk/guidance/find-and-use-data-on-public-electric-vehicle-chargepoints)

# %% [markdown]
# **Data Description**

# %% [markdown]
# **EV_data**
#
# **Brand** - Manufacturer of the car
#
# **Model** - Model name
#
# **Accel** - Aceleration as 0-100 km/h
#
# **TopSpeed** - Top speed in km/h
#
# **Range** - Range of car in km
#
# **Efficiency** - Efficiency of the car
#
# **FastCharge** - Charge km/h
#
# **RapidCharge** - Rapid charge possible or not
#
# **PowerTrain** - Front, rear or all wheel drive
#
# **PlugType** - Plug type
#
# **BodyStyle** -Style of car
#
# **Segment** - Market segment
#
# **Seats** - Number of seats
#
# **PriceEuro** - Price in Euros

# %% [markdown]
# **FEV_data**
#
# **Car full name** - Full name of the car
#
# **Make** - Brand name
#
# **Model** - Model name
#
# **Minimal price (gross) [PLN]** - Price in Polish Zloty
#
# **Engine power[km]** - Engine power
#
# **Maximum torque[Nm]** - Maximum torque
#
# **Type of breaks** - Brake types
#
# **Drive type** - Drive type
#
# **Battery capacity[kWh]** - Battery capacity
#
# **Range [WLTP][km]** - E=Range of the car [Worldwide Harmonised Light Vehicle Test Procedure]
#
# **Wheelbase[cm]** - Wheelbase in centimeters
#
# **Length[cm]** - Length of car
#
# **Width[cm]** - Width of car
#
# **Height[cm]** - Height of car
#
# **Minimal empty weight[kg]** - Minimal weight
#
# **Permissible gross weight[kg]** - Gross weight
#
# **Maximum load capacity[kg]** - Maximum load
#
# **Number of seats** - Number of seats in car
#
# **Number of doors** - Number of doors in the car
#
# **Tire size[in]** - Size of tire in inches
#
# **Maximum speed[kph]** - Maximum speed of car
#
# **Boot capacity(VDA)[l]** - Length of the boot
#
# **Acceleration 0-100 kph[s]** - Acceleration
#
# **Maximum DC charging power[kw]** - Charging capacity
#
# **mean - Energy consumption[kWh/100km]** - Energy consumed by the car

# %% [markdown]
# # **DATA PREPARATION**

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Load the first data set

# %%
url1 = 'https://github.com/JoLRThomson/CMM202JoT/blob/main/ElectricCarData_Norm.csv?raw=1'
EV_data = pd.read_csv(url1)
EV_data.head()
# Out:
#          Brand                          Model     Accel  TopSpeed   Range  \
# 0       Tesla   Model 3 Long Range Dual Motor   4.6 sec  233 km/h  450 km
# 1  Volkswagen                       ID.3 Pure  10.0 sec  160 km/h  270 km
# 2    Polestar                               2   4.7 sec  210 km/h  400 km
# 3         BMW                            iX3    6.8 sec  180 km/h  360 km
# 4       Honda                              e    9.5 sec  145 km/h  170 km
#
#   Efficiency FastCharge              RapidCharge        PowerTrain  \
# 0  161 Wh/km   940 km/h  Rapid charging possible   All Wheel Drive
# 1  167 Wh/km   250 km/h  Rapid charging possible  Rear Wheel Drive
# 2  181 Wh/km   620 km/h  Rapid charging possible   All Wheel Drive
# 3  206 Wh/km   560 km/h  Rapid charging possible  Rear Wheel Drive
# 4  168 Wh/km   190 km/h  Rapid charging possible  Rear Wheel Drive
#
#      PlugType  BodyStyle Segment  Seats  PriceEuro
# 0  Type 2 CCS      Sedan       D      5      55480
# 1  Type 2 CCS  Hatchback       C      5      30000
# 2  Type 2 CCS   Liftback       D      5      56440
# 3  Type 2 CCS        SUV       D      5      68040
# 4  Type 2 CCS  Hatchback       B      4      32997

# %% [markdown]
# Load the 2nd data set

# %%
url2 = 'https://github.com/JoLRThomson/CMM202JoT/blob/main/FEV-data.csv?raw=1'
FEV_data = pd.read_csv(url2, encoding = 'latin1')
FEV_data.head()
# Out:
#                       Car full name  Make                        Model  \
# 0            Audi e-tron 55 quattro  Audi            e-tron 55 quattro
# 1            Audi e-tron 50 quattro  Audi            e-tron 50 quattro
# 2             Audi e-tron S quattro  Audi             e-tron S quattro
# 3  Audi e-tron Sportback 50 quattro  Audi  e-tron Sportback 50 quattro
# 4  Audi e-tron Sportback 55 quattro  Audi  e-tron Sportback 55 quattro
#
#    Minimal price (gross) [PLN]  Engine power [KM]  Maximum torque [Nm]  \
# 0                       345700                360                  664
# 1                       308400                313                  540
# 2                       414900                503                  973
# 3                       319700                313                  540
# 4                       357000                360                  664
#
#         Type of brakes Drive type  Battery capacity [kWh]  Range (WLTP) [km]  \
# 0  disc (front + rear)        4WD                    95.0                438
# 1  disc (front + rear)        4WD                    71.0                340
# 2  disc (front + rear)        4WD                    95.0                364
# 3  disc (front + rear)        4WD                    71.0                346
# 4  disc (front + rear)        4WD                    95.0                447
#
#    Wheelbase [cm]  Length [cm]  Width [cm]  Height [cm]  \
# 0           292.8        490.1       193.5        162.9
# 1           292.8        490.1       193.5        162.9
# 2           292.8        490.2       197.6        162.9
# 3           292.8        490.1       193.5        161.6
# 4           292.8        490.1       193.5        161.6
#
#    Minimal empty weight [kg]  Permissable gross weight [kg]  \
# 0                       2565                         3130.0
# 1                       2445                         3040.0
# 2                       2695                         3130.0
# 3                       2445                         3040.0
# 4                       2595                         3130.0
#
#    Maximum load capacity [kg]  Number of seats  Number of doors  \
# 0                       640.0                5                5
# 1                       670.0                5                5
# 2                       565.0                5                5
# 3                       640.0                5                5
# 4                       670.0                5                5
#
#    Tire size [in]  Maximum speed [kph]  Boot capacity (VDA) [l]  \
# 0              19                  200                    660.0
# 1              19                  190                    660.0
# 2              20                  210                    660.0
# 3              19                  190                    615.0
# 4              19                  200                    615.0
#
#    Acceleration 0-100 kph [s]  Maximum DC charging power [kW]  \
# 0                         5.7                             150
# 1                         6.8                             150
# 2                         4.5                             150
# 3                         6.8                             150
# 4                         5.7                             150
#
#    mean - Energy consumption [kWh/100 km]
# 0                                   24.45
# 1                                   23.80
# 2                                   27.55
# 3                                   23.30
# 4                                   23.85

# %% [markdown]
# Cleaning the first data set

# %%
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)

# functions to clean the data
def clean_accel(col):
    return col.strip('sec ')

def clean_speed(col):
    return col.strip('km/h ')

def clean_range(col):
    return col.strip('km ')

def clean_efficiency(col):
    return col.strip('Wh/km ')

def clean_fast_charge(col):
    return col.strip('km/h ')
       
def clean_power_train(col):
    return col.replace(' Wheel Drive', '')

# apply functions to columns
EV_data['Accel'] = EV_data['Accel'].apply(clean_accel)
EV_data['TopSpeed'] = EV_data['TopSpeed'].apply(clean_speed)
EV_data['Range'] = EV_data['Range'].apply(clean_range)
EV_data['Efficiency'] = EV_data['Efficiency'].apply(clean_efficiency)
EV_data['FastCharge'] = EV_data['FastCharge'].apply(clean_fast_charge)
EV_data['PowerTrain'] = EV_data['PowerTrain'].apply(clean_power_train)

# mapping for yes and no values
mapping = {'Rapid charging possible':'Yes', 'Rapid charging not possible':'No'}
EV_data['RapidCharge'] = EV_data['RapidCharge'].map(mapping)

# deal with missing values
EV_data['FastCharge'] = EV_data['FastCharge'].replace('-', np.nan)

# create a new column called car full name which is make + model to allow merging of both datasets
EV_data['Car full name'] = EV_data['Brand']+EV_data['Model']

# create a new column for segment description 
seg_desc = {'A':'Mini', 'B':'Supermini', 'C':'Small Family', 'D':'Large Family', 'E':'Executive', 'F':'Luxury', 'S':'Sport', 'N':'Commercial'}
EV_data['Segment Description'] = EV_data['Segment'].map(seg_desc)

# remove unwanted columns
EV_data = EV_data.drop(labels=['Model'], axis=1)

# rename columns
EV_data = EV_data.rename(columns= {'Accel':'Acceleration 0-100 kph[s]', 'TopSpeed':'Maximum speed [kph]', 'Range':'Range (WLTP) [km]', 'Efficiency':'Battery efficiency [Wh/km]', 'FastCharge':'Rate of charge [km/h]', 'RapidCharge':'Rapid Charge Possible?'})

EV_data.head()
# Out:
#          Brand Acceleration 0-100 kph[s] Maximum speed [kph]  \
# 0       Tesla                        4.6                 233
# 1  Volkswagen                       10.0                 160
# 2    Polestar                        4.7                 210
# 3         BMW                        6.8                 180
# 4       Honda                        9.5                 145
#
#   Range (WLTP) [km] Battery efficiency [Wh/km] Rate of charge [km/h]  \
# 0               450                        161                   940
# 1               270                        167                   250
# 2               400                        181                   620
# 3               360                        206                   560
# 4               170                        168                   190
#
#   Rapid Charge Possible? PowerTrain    PlugType  BodyStyle Segment  Seats  \
# 0                    Yes        All  Type 2 CCS      Sedan       D      5
# 1                    Yes       Rear  Type 2 CCS  Hatchback       C      5
# 2                    Yes        All  Type 2 CCS   Liftback       D      5
# 3                    Yes       Rear  Type 2 CCS        SUV       D      5
# 4                    Yes       Rear  Type 2 CCS  Hatchback       B      4
#
#    PriceEuro                        Car full name Segment Description
# 0      55480  Tesla Model 3 Long Range Dual Motor        Large Family
# 1      30000                 Volkswagen ID.3 Pure        Small Family
# 2      56440                           Polestar 2        Large Family
# 3      68040                             BMW iX3         Large Family
# 4      32997                             Honda e            Supermini

# %% [markdown]
# Remove whitespace from car names to allow merge on car names

# %%
EV_data['Car full name'] = EV_data['Car full name'].str.strip()

# %% [markdown]
# Set 'Car full name' to be the index

# %%
EV_data = EV_data.set_index('Car full name', drop=True)
EV_data = EV_data.sort_index()

# %% [markdown]
# Check for duplicate car names in index

# %%
EV_data.index.is_unique # this shows there are duplicate car names in the index
# Out:
# False

# %% [markdown]
# Upon inspection of values there are two rows for 'Kia e-Soul 64 kWh' with different values for 'Rate of charge (km/hr)'

# %%
EV_data.loc['Kia e-Soul 64 kWh']
# Out:
#                   Brand Acceleration 0-100 kph[s] Maximum speed [kph]  \
# Car full name
# Kia e-Soul 64 kWh  Kia                        7.9                 167
# Kia e-Soul 64 kWh  Kia                        7.9                 167
#
#                   Range (WLTP) [km] Battery efficiency [Wh/km]  \
# Car full name
# Kia e-Soul 64 kWh               365                        175
# Kia e-Soul 64 kWh               365                        175
#
#                   Rate of charge [km/h] Rapid Charge Possible? PowerTrain  \
# Car full name
# Kia e-Soul 64 kWh                   320                    Yes      Front
# Kia e-Soul 64 kWh                   340                    Yes      Front
#
#                      PlugType BodyStyle Segment  Seats  PriceEuro  \
# Car full name
# Kia e-Soul 64 kWh  Type 2 CCS       SUV       B      5      36837
# Kia e-Soul 64 kWh  Type 2 CCS       SUV       B      5      36837
#
#                   Segment Description
# Car full name
# Kia e-Soul 64 kWh           Supermini
# Kia e-Soul 64 kWh           Supermini

# %%
EV_data.loc['Kia e-Soul 64 kWh']['Rate of charge [km/h]']
# Out:
# Car full name
# Kia e-Soul 64 kWh    320
# Kia e-Soul 64 kWh    340
# Name: Rate of charge [km/h], dtype: object

# %% [markdown]
# Replace value 320 with 340 so both rows contain identical values. This will allow removal of the duplicated row. First, identify location of value to be replaced.

# %%
EV_data.iloc[35]
# Out:
# Brand                               Kia
# Acceleration 0-100 kph[s]            7.9
# Maximum speed [kph]                  167
# Range (WLTP) [km]                    365
# Battery efficiency [Wh/km]           175
# Rate of charge [km/h]                320
# Rapid Charge Possible?               Yes
# PowerTrain                         Front
# PlugType                      Type 2 CCS
# BodyStyle                            SUV
# Segment                                B
# Seats                                  5
# PriceEuro                          36837
# Segment Description            Supermini
# Name: Kia e-Soul 64 kWh, dtype: object

# %%
EV_data.iat[35, 5]
# Out:
# '320'

# %% [markdown]
# Now change this value from 320 to 340

# %%
EV_data.iat[35, 5] = '340'
EV_data.iloc[35]
# Out:
# Brand                               Kia
# Acceleration 0-100 kph[s]            7.9
# Maximum speed [kph]                  167
# Range (WLTP) [km]                    365
# Battery efficiency [Wh/km]           175
# Rate of charge [km/h]                340
# Rapid Charge Possible?               Yes
# PowerTrain                         Front
# PlugType                      Type 2 CCS
# BodyStyle                            SUV
# Segment                                B
# Seats                                  5
# PriceEuro                          36837
# Segment Description            Supermini
# Name: Kia e-Soul 64 kWh, dtype: object

# %% [markdown]
# Remove unwanted columns from FEV_data

# %%
FEV_data = FEV_data.drop(labels=['Model', 'Drive type', 'Range (WLTP) [km]','Number of seats', 'Number of doors'], axis=1)
# set index to car full name sorted a to z and convert to string
FEV_data = FEV_data.set_index('Car full name', drop=True)
FEV_data.index = FEV_data.index.map(str)
FEV_data = FEV_data.sort_index(ascending=True)
FEV_data.head()
# Out:
#                                   Make  Minimal price (gross) [PLN]  \
# Car full name
# Audi e-tron 50 quattro            Audi                       308400
# Audi e-tron 55 quattro            Audi                       345700
# Audi e-tron S quattro             Audi                       414900
# Audi e-tron Sportback 50 quattro  Audi                       319700
# Audi e-tron Sportback 55 quattro  Audi                       357000
#
#                                   Engine power [KM]  Maximum torque [Nm]  \
# Car full name
# Audi e-tron 50 quattro                          313                  540
# Audi e-tron 55 quattro                          360                  664
# Audi e-tron S quattro                           503                  973
# Audi e-tron Sportback 50 quattro                313                  540
# Audi e-tron Sportback 55 quattro                360                  664
#
#                                        Type of brakes  Battery capacity [kWh]  \
# Car full name
# Audi e-tron 50 quattro            disc (front + rear)                    71.0
# Audi e-tron 55 quattro            disc (front + rear)                    95.0
# Audi e-tron S quattro             disc (front + rear)                    95.0
# Audi e-tron Sportback 50 quattro  disc (front + rear)                    71.0
# Audi e-tron Sportback 55 quattro  disc (front + rear)                    95.0
#
#                                   Wheelbase [cm]  Length [cm]  Width [cm]  \
# Car full name
# Audi e-tron 50 quattro                     292.8        490.1       193.5
# Audi e-tron 55 quattro                     292.8        490.1       193.5
# Audi e-tron S quattro                      292.8        490.2       197.6
# Audi e-tron Sportback 50 quattro           292.8        490.1       193.5
# Audi e-tron Sportback 55 quattro           292.8        490.1       193.5
#
#                                   Height [cm]  Minimal empty weight [kg]  \
# Car full name
# Audi e-tron 50 quattro                  162.9                       2445
# Audi e-tron 55 quattro                  162.9                       2565
# Audi e-tron S quattro                   162.9                       2695
# Audi e-tron Sportback 50 quattro        161.6                       2445
# Audi e-tron Sportback 55 quattro        161.6                       2595
#
#                                   Permissable gross weight [kg]  \
# Car full name
# Audi e-tron 50 quattro                                   3040.0
# Audi e-tron 55 quattro                                   3130.0
# Audi e-tron S quattro                                    3130.0
# Audi e-tron Sportback 50 quattro                         3040.0
# Audi e-tron Sportback 55 quattro                         3130.0
#
#                                   Maximum load capacity [kg]  Tire size [in]  \
# Car full name
# Audi e-tron 50 quattro                                 670.0              19
# Audi e-tron 55 quattro                                 640.0              19
# Audi e-tron S quattro                                  565.0              20
# Audi e-tron Sportback 50 quattro                       640.0              19
# Audi e-tron Sportback 55 quattro                       670.0              19
#
#                                   Maximum speed [kph]  \
# Car full name
# Audi e-tron 50 quattro                            190
# Audi e-tron 55 quattro                            200
# Audi e-tron S quattro                             210
# Audi e-tron Sportback 50 quattro                  190
# Audi e-tron Sportback 55 quattro                  200
#
#                                   Boot capacity (VDA) [l]  \
# Car full name
# Audi e-tron 50 quattro                              660.0
# Audi e-tron 55 quattro                              660.0
# Audi e-tron S quattro                               660.0
# Audi e-tron Sportback 50 quattro                    615.0
# Audi e-tron Sportback 55 quattro                    615.0
#
#                                   Acceleration 0-100 kph [s]  \
# Car full name
# Audi e-tron 50 quattro                                   6.8
# Audi e-tron 55 quattro                                   5.7
# Audi e-tron S quattro                                    4.5
# Audi e-tron Sportback 50 quattro                         6.8
# Audi e-tron Sportback 55 quattro                         5.7
#
#                                   Maximum DC charging power [kW]  \
# Car full name
# Audi e-tron 50 quattro                                       150
# Audi e-tron 55 quattro                                       150
# Audi e-tron S quattro                                        150
# Audi e-tron Sportback 50 quattro                             150
# Audi e-tron Sportback 55 quattro                             150
#
#                                   mean - Energy consumption [kWh/100 km]
# Car full name
# Audi e-tron 50 quattro                                             23.80
# Audi e-tron 55 quattro                                             24.45
# Audi e-tron S quattro                                              27.55
# Audi e-tron Sportback 50 quattro                                   23.30
# Audi e-tron Sportback 55 quattro                                   23.85

# %% [markdown]
# Rename index values to ensure consistency in car name across both sets of data

# %%
FEV_data = FEV_data.rename(index={'Volkswagen e-up!':'Volkswagen e-Up!', 
                                  'Volkswagen ID.4 1st':'Volkswagen ID.4', 
                                  'Tesla Model X Long Range Plus':'Tesla Model X Long Range',
                                  'Tesla Model S Long Range Plus':'Tesla Model S Long Range',
                                  'Tesla Model 3 Performance':'Tesla Model 3 Long Range Performance',
                                  'Tesla Model 3 Long Range':'Tesla Model 3 Long Range Dual Motor',
                                  'Smart fortwo EQ':'Smart EQ fortwo coupe',
                                  'Smart forfour EQ':'Smart EQ forfour',
                                  'Skoda Citigo-e iV':'Skoda CITIGOe iV',
                                  'Renault Zoe R135':'Renault Zoe ZE50 R135',
                                  'Renault Zoe R110':'Renault Zoe ZE50 R110',
                                  'Porsche Taycan 4S (Performance)':'Porsche Taycan 4S',
                                  'Porsche Taycan 4S (Performance Plus)':'Porsche Taycan 4S Plus',
                                  'Peugeot e-2008':'Peugeot e-2008 SUV',
                                  'Nissan e-NV200 evalia':'Nissan e-NV200 Evalia',
                                  'Mercedes-Benz EQV (long)':'Mercedes EQV 300 Long',
                                  'Mercedes-Benz EQC':'Mercedes EQC 400 4MATIC',
                                  'Kia e-Soul 64kWh':'Kia e-Soul 64 kWh',
                                  'Kia e-Soul 39.2kWh':'Kia e-Soul 39 kWh',
                                  'Kia e-Niro 64kWh':'Kia e-Niro 64 kWh',
                                  'Kia e-Niro 39.2kWh':'Kia e-Niro 39 kWh',
                                  'Hyundai Kona electric 64kWh':'Hyundai Kona Electric 64 kWh',
                                  'Hyundai Kona electric 39.2kWh':'Hyundai Kona Electric 39 kWh',
                                  'Hyundai Ioniq electric':'Hyundai IONIQ Electric',
                                  'DS DS3 Crossback e-tense':'DS 3 Crossback E-Tense',
                                  'Citron -C4':'Citroen e-C4',
                                  'Citron -Spacetourer (M)': 'Citroen e-Spacetourer (M)',
                                  'BMW i3s':'BMW i3s 120 Ah',
                                  'BMW i3':'BMW i3 120 Ah',
                                  'Audi e-tron Sportback S quattro':'Audi e-tron S Sportback 55 quattro',
                                  'Audi e-tron S quattro':'Audi e-tron S 55 quattro'})

# %% [markdown]
# Merge both sets of data keeping all the data from EV_data

# %%
EV_Merged = pd.merge(EV_data, FEV_data, on='Car full name', how='inner')
EV_Merged = EV_Merged.sort_index(ascending=True)
EV_Merged.index.is_unique
# Out:
# False

# %%
len(EV_Merged)
# Out:
# 52

# %%
EV_Merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 52 entries, Audi e-tron 50 quattro to Volkswagen e-Up!
# Data columns (total 33 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Brand                                   52 non-null     object
#  1   Acceleration 0-100 kph[s]               52 non-null     object
#  2   Maximum speed [kph]_x                   52 non-null     object
#  3   Range (WLTP) [km]                       52 non-null     object
#  4   Battery efficiency [Wh/km]              52 non-null     object
#  5   Rate of charge [km/h]                   50 non-null     object
#  6   Rapid Charge Possible?                  52 non-null     object
#  7   PowerTrain                              52 non-null     object
#  8   PlugType                                52 non-null     object
#  9   BodyStyle                               52 non-null     object
#  10  Segment                                 52 non-null     object
#  11  Seats                                   52 non-null     int64
#  12  PriceEuro                               52 non-null     int64
#  13  Segment Description                     52 non-null     object
#  14  Make                                    52 non-null     object
#  15  Minimal price (gross) [PLN]             52 non-null     int64
#  16  Engine power [KM]                       52 non-null     int64
#  17  Maximum torque [Nm]                     52 non-null     int64
#  18  Type of brakes                          51 non-null     object
#  19  Battery capacity [kWh]                  52 non-null     float64
#  20  Wheelbase [cm]                          52 non-null     float64
#  21  Length [cm]                             52 non-null     float64
#  22  Width [cm]                              52 non-null     float64
#  23  Height [cm]                             52 non-null     float64
#  24  Minimal empty weight [kg]               52 non-null     int64
#  25  Permissable gross weight [kg]           44 non-null     float64
#  26  Maximum load capacity [kg]              44 non-null     float64
#  27  Tire size [in]                          52 non-null     int64
#  28  Maximum speed [kph]_y                   52 non-null     int64
#  29  Boot capacity (VDA) [l]                 51 non-null     float64
#  30  Acceleration 0-100 kph [s]              49 non-null     float64
#  31  Maximum DC charging power [kW]          52 non-null     int64
#  32  mean - Energy consumption [kWh/100 km]  44 non-null     float64
# dtypes: float64(10), int64(9), object(14)
# memory usage: 15.9+ KB

# %% [markdown]
# Now we can remove the duplicated row from the merged dataframe

# %%
EV_Merged = EV_Merged.drop_duplicates()
EV_Merged.index.is_unique
# Out:
# True

# %%
EV_Merged['Brand'] = EV_Merged['Brand'].dropna()
EV_Merged.head()
# Out:
#                                     Brand Acceleration 0-100 kph[s]  \
# Car full name
# Audi e-tron 50 quattro              Audi                        6.8
# Audi e-tron 55 quattro              Audi                        5.7
# Audi e-tron S 55 quattro            Audi                        4.5
# Audi e-tron S Sportback 55 quattro  Audi                        4.5
# Audi e-tron Sportback 50 quattro    Audi                        6.8
#
#                                    Maximum speed [kph]_x Range (WLTP) [km]  \
# Car full name
# Audi e-tron 50 quattro                               190               280
# Audi e-tron 55 quattro                               200               365
# Audi e-tron S 55 quattro                             210               320
# Audi e-tron S Sportback 55 quattro                   210               335
# Audi e-tron Sportback 50 quattro                     190               295
#
#                                    Battery efficiency [Wh/km]  \
# Car full name
# Audi e-tron 50 quattro                                    231
# Audi e-tron 55 quattro                                    237
# Audi e-tron S 55 quattro                                  270
# Audi e-tron S Sportback 55 quattro                        258
# Audi e-tron Sportback 50 quattro                          219
#
#                                    Rate of charge [km/h]  \
# Car full name
# Audi e-tron 50 quattro                               450
# Audi e-tron 55 quattro                               590
# Audi e-tron S 55 quattro                             510
# Audi e-tron S Sportback 55 quattro                   540
# Audi e-tron Sportback 50 quattro                     470
#
#                                    Rapid Charge Possible? PowerTrain  \
# Car full name
# Audi e-tron 50 quattro                                Yes        All
# Audi e-tron 55 quattro                                Yes        All
# Audi e-tron S 55 quattro                              Yes        All
# Audi e-tron S Sportback 55 quattro                    Yes        All
# Audi e-tron Sportback 50 quattro                      Yes        All
#
#                                       PlugType BodyStyle Segment  Seats  \
# Car full name
# Audi e-tron 50 quattro              Type 2 CCS       SUV       E      5
# Audi e-tron 55 quattro              Type 2 CCS       SUV       E      5
# Audi e-tron S 55 quattro            Type 2 CCS       SUV       E      5
# Audi e-tron S Sportback 55 quattro  Type 2 CCS       SUV       E      5
# Audi e-tron Sportback 50 quattro    Type 2 CCS       SUV       E      5
#
#                                     PriceEuro Segment Description  Make  \
# Car full name
# Audi e-tron 50 quattro                  67358           Executive  Audi
# Audi e-tron 55 quattro                  79445           Executive  Audi
# Audi e-tron S 55 quattro                93800           Executive  Audi
# Audi e-tron S Sportback 55 quattro      96050           Executive  Audi
# Audi e-tron Sportback 50 quattro        69551           Executive  Audi
#
#                                     Minimal price (gross) [PLN]  \
# Car full name
# Audi e-tron 50 quattro                                   308400
# Audi e-tron 55 quattro                                   345700
# Audi e-tron S 55 quattro                                 414900
# Audi e-tron S Sportback 55 quattro                       426200
# Audi e-tron Sportback 50 quattro                         319700
#
#                                     Engine power [KM]  Maximum torque [Nm]  \
# Car full name
# Audi e-tron 50 quattro                            313                  540
# Audi e-tron 55 quattro                            360                  664
# Audi e-tron S 55 quattro                          503                  973
# Audi e-tron S Sportback 55 quattro                503                  973
# Audi e-tron Sportback 50 quattro                  313                  540
#
#                                          Type of brakes  \
# Car full name
# Audi e-tron 50 quattro              disc (front + rear)
# Audi e-tron 55 quattro              disc (front + rear)
# Audi e-tron S 55 quattro            disc (front + rear)
# Audi e-tron S Sportback 55 quattro  disc (front + rear)
# Audi e-tron Sportback 50 quattro    disc (front + rear)
#
#                                     Battery capacity [kWh]  Wheelbase [cm]  \
# Car full name
# Audi e-tron 50 quattro                                71.0           292.8
# Audi e-tron 55 quattro                                95.0           292.8
# Audi e-tron S 55 quattro                              95.0           292.8
# Audi e-tron S Sportback 55 quattro                    95.0           292.8
# Audi e-tron Sportback 50 quattro                      71.0           292.8
#
#                                     Length [cm]  Width [cm]  Height [cm]  \
# Car full name
# Audi e-tron 50 quattro                    490.1       193.5        162.9
# Audi e-tron 55 quattro                    490.1       193.5        162.9
# Audi e-tron S 55 quattro                  490.2       197.6        162.9
# Audi e-tron S Sportback 55 quattro        490.2       197.6        161.5
# Audi e-tron Sportback 50 quattro          490.1       193.5        161.6
#
#                                     Minimal empty weight [kg]  \
# Car full name
# Audi e-tron 50 quattro                                   2445
# Audi e-tron 55 quattro                                   2565
# Audi e-tron S 55 quattro                                 2695
# Audi e-tron S Sportback 55 quattro                       2695
# Audi e-tron Sportback 50 quattro                         2445
#
#                                     Permissable gross weight [kg]  \
# Car full name
# Audi e-tron 50 quattro                                     3040.0
# Audi e-tron 55 quattro                                     3130.0
# Audi e-tron S 55 quattro                                   3130.0
# Audi e-tron S Sportback 55 quattro                         3130.0
# Audi e-tron Sportback 50 quattro                           3040.0
#
#                                     Maximum load capacity [kg]  \
# Car full name
# Audi e-tron 50 quattro                                   670.0
# Audi e-tron 55 quattro                                   640.0
# Audi e-tron S 55 quattro                                 565.0
# Audi e-tron S Sportback 55 quattro                       565.0
# Audi e-tron Sportback 50 quattro                         640.0
#
#                                     Tire size [in]  Maximum speed [kph]_y  \
# Car full name
# Audi e-tron 50 quattro                          19                    190
# Audi e-tron 55 quattro                          19                    200
# Audi e-tron S 55 quattro                        20                    210
# Audi e-tron S Sportback 55 quattro              20                    210
# Audi e-tron Sportback 50 quattro                19                    190
#
#                                     Boot capacity (VDA) [l]  \
# Car full name
# Audi e-tron 50 quattro                                660.0
# Audi e-tron 55 quattro                                660.0
# Audi e-tron S 55 quattro                              660.0
# Audi e-tron S Sportback 55 quattro                    615.0
# Audi e-tron Sportback 50 quattro                      615.0
#
#                                     Acceleration 0-100 kph [s]  \
# Car full name
# Audi e-tron 50 quattro                                     6.8
# Audi e-tron 55 quattro                                     5.7
# Audi e-tron S 55 quattro                                   4.5
# Audi e-tron S Sportback 55 quattro                         4.5
# Audi e-tron Sportback 50 quattro                           6.8
#
#                                     Maximum DC charging power [kW]  \
# Car full name
# Audi e-tron 50 quattro                                         150
# Audi e-tron 55 quattro                                         150
# Audi e-tron S 55 quattro                                       150
# Audi e-tron S Sportback 55 quattro                             150
# Audi e-tron Sportback 50 quattro                               150
#
#                                     mean - Energy consumption [kWh/100 km]
# Car full name
# Audi e-tron 50 quattro                                               23.80
# Audi e-tron 55 quattro                                               24.45
# Audi e-tron S 55 quattro                                             27.55
# Audi e-tron S Sportback 55 quattro                                   27.20
# Audi e-tron Sportback 50 quattro                                     23.30

# %% [markdown]
# Change some columns data type to float and int

# %%
EV_Merged = EV_Merged.astype({"Acceleration 0-100 kph[s]":"float"})
EV_Merged = EV_Merged.astype({"Battery efficiency [Wh/km]":"int"})
EV_Merged = EV_Merged.astype({"Rate of charge [km/h]":"float"})
EV_Merged = EV_Merged.astype({"Maximum speed [kph]_x":"int"})
EV_Merged = EV_Merged.astype({"Range (WLTP) [km]": "int"})
print(EV_Merged.dtypes)
# Out:
# Brand                                      object
# Acceleration 0-100 kph[s]                 float64
# Maximum speed [kph]_x                       int64
# Range (WLTP) [km]                           int64
# Battery efficiency [Wh/km]                  int64
# Rate of charge [km/h]                     float64
# Rapid Charge Possible?                     object
# PowerTrain                                 object
# PlugType                                   object
# BodyStyle                                  object
# Segment                                    object
# Seats                                       int64
# PriceEuro                                   int64
# Segment Description                        object
# Make                                       object
# Minimal price (gross) [PLN]                 int64
# Engine power [KM]                           int64
# Maximum torque [Nm]                         int64
# Type of brakes                             object
# Battery capacity [kWh]                    float64
# Wheelbase [cm]                            float64
# Length [cm]                               float64
# Width [cm]                                float64
# Height [cm]                               float64
# Minimal empty weight [kg]                   int64
# Permissable gross weight [kg]             float64
# Maximum load capacity [kg]                float64
# Tire size [in]                              int64
# Maximum speed [kph]_y                       int64
# Boot capacity (VDA) [l]                   float64
# Acceleration 0-100 kph [s]                float64
# Maximum DC charging power [kW]              int64
# mean - Energy consumption [kWh/100 km]    float64
# dtype: object

# %%
EV_Merged = EV_Merged.rename(columns= {'Brand' : 'Car Brand', 
                                       'Boot capacity (VDA) [l]' : 'Boot capacity', 
                                       'Maximum DC charging power [kW]' : 'Maximum charging power', 
                                       'mean - Energy consumption [kWh/100 km]' : 'Mean Energy Consumption'})

#rename some columns for better usability

# %%
EV_Merged.head()
# Out:
#                                    Car Brand  Acceleration 0-100 kph[s]  \
# Car full name
# Audi e-tron 50 quattro                 Audi                         6.8
# Audi e-tron 55 quattro                 Audi                         5.7
# Audi e-tron S 55 quattro               Audi                         4.5
# Audi e-tron S Sportback 55 quattro     Audi                         4.5
# Audi e-tron Sportback 50 quattro       Audi                         6.8
#
#                                     Maximum speed [kph]_x  Range (WLTP) [km]  \
# Car full name
# Audi e-tron 50 quattro                                190                280
# Audi e-tron 55 quattro                                200                365
# Audi e-tron S 55 quattro                              210                320
# Audi e-tron S Sportback 55 quattro                    210                335
# Audi e-tron Sportback 50 quattro                      190                295
#
#                                     Battery efficiency [Wh/km]  \
# Car full name
# Audi e-tron 50 quattro                                     231
# Audi e-tron 55 quattro                                     237
# Audi e-tron S 55 quattro                                   270
# Audi e-tron S Sportback 55 quattro                         258
# Audi e-tron Sportback 50 quattro                           219
#
#                                     Rate of charge [km/h]  \
# Car full name
# Audi e-tron 50 quattro                              450.0
# Audi e-tron 55 quattro                              590.0
# Audi e-tron S 55 quattro                            510.0
# Audi e-tron S Sportback 55 quattro                  540.0
# Audi e-tron Sportback 50 quattro                    470.0
#
#                                    Rapid Charge Possible? PowerTrain  \
# Car full name
# Audi e-tron 50 quattro                                Yes        All
# Audi e-tron 55 quattro                                Yes        All
# Audi e-tron S 55 quattro                              Yes        All
# Audi e-tron S Sportback 55 quattro                    Yes        All
# Audi e-tron Sportback 50 quattro                      Yes        All
#
#                                       PlugType BodyStyle Segment  Seats  \
# Car full name
# Audi e-tron 50 quattro              Type 2 CCS       SUV       E      5
# Audi e-tron 55 quattro              Type 2 CCS       SUV       E      5
# Audi e-tron S 55 quattro            Type 2 CCS       SUV       E      5
# Audi e-tron S Sportback 55 quattro  Type 2 CCS       SUV       E      5
# Audi e-tron Sportback 50 quattro    Type 2 CCS       SUV       E      5
#
#                                     PriceEuro Segment Description  Make  \
# Car full name
# Audi e-tron 50 quattro                  67358           Executive  Audi
# Audi e-tron 55 quattro                  79445           Executive  Audi
# Audi e-tron S 55 quattro                93800           Executive  Audi
# Audi e-tron S Sportback 55 quattro      96050           Executive  Audi
# Audi e-tron Sportback 50 quattro        69551           Executive  Audi
#
#                                     Minimal price (gross) [PLN]  \
# Car full name
# Audi e-tron 50 quattro                                   308400
# Audi e-tron 55 quattro                                   345700
# Audi e-tron S 55 quattro                                 414900
# Audi e-tron S Sportback 55 quattro                       426200
# Audi e-tron Sportback 50 quattro                         319700
#
#                                     Engine power [KM]  Maximum torque [Nm]  \
# Car full name
# Audi e-tron 50 quattro                            313                  540
# Audi e-tron 55 quattro                            360                  664
# Audi e-tron S 55 quattro                          503                  973
# Audi e-tron S Sportback 55 quattro                503                  973
# Audi e-tron Sportback 50 quattro                  313                  540
#
#                                          Type of brakes  \
# Car full name
# Audi e-tron 50 quattro              disc (front + rear)
# Audi e-tron 55 quattro              disc (front + rear)
# Audi e-tron S 55 quattro            disc (front + rear)
# Audi e-tron S Sportback 55 quattro  disc (front + rear)
# Audi e-tron Sportback 50 quattro    disc (front + rear)
#
#                                     Battery capacity [kWh]  Wheelbase [cm]  \
# Car full name
# Audi e-tron 50 quattro                                71.0           292.8
# Audi e-tron 55 quattro                                95.0           292.8
# Audi e-tron S 55 quattro                              95.0           292.8
# Audi e-tron S Sportback 55 quattro                    95.0           292.8
# Audi e-tron Sportback 50 quattro                      71.0           292.8
#
#                                     Length [cm]  Width [cm]  Height [cm]  \
# Car full name
# Audi e-tron 50 quattro                    490.1       193.5        162.9
# Audi e-tron 55 quattro                    490.1       193.5        162.9
# Audi e-tron S 55 quattro                  490.2       197.6        162.9
# Audi e-tron S Sportback 55 quattro        490.2       197.6        161.5
# Audi e-tron Sportback 50 quattro          490.1       193.5        161.6
#
#                                     Minimal empty weight [kg]  \
# Car full name
# Audi e-tron 50 quattro                                   2445
# Audi e-tron 55 quattro                                   2565
# Audi e-tron S 55 quattro                                 2695
# Audi e-tron S Sportback 55 quattro                       2695
# Audi e-tron Sportback 50 quattro                         2445
#
#                                     Permissable gross weight [kg]  \
# Car full name
# Audi e-tron 50 quattro                                     3040.0
# Audi e-tron 55 quattro                                     3130.0
# Audi e-tron S 55 quattro                                   3130.0
# Audi e-tron S Sportback 55 quattro                         3130.0
# Audi e-tron Sportback 50 quattro                           3040.0
#
#                                     Maximum load capacity [kg]  \
# Car full name
# Audi e-tron 50 quattro                                   670.0
# Audi e-tron 55 quattro                                   640.0
# Audi e-tron S 55 quattro                                 565.0
# Audi e-tron S Sportback 55 quattro                       565.0
# Audi e-tron Sportback 50 quattro                         640.0
#
#                                     Tire size [in]  Maximum speed [kph]_y  \
# Car full name
# Audi e-tron 50 quattro                          19                    190
# Audi e-tron 55 quattro                          19                    200
# Audi e-tron S 55 quattro                        20                    210
# Audi e-tron S Sportback 55 quattro              20                    210
# Audi e-tron Sportback 50 quattro                19                    190
#
#                                     Boot capacity  Acceleration 0-100 kph [s]  \
# Car full name
# Audi e-tron 50 quattro                      660.0                         6.8
# Audi e-tron 55 quattro                      660.0                         5.7
# Audi e-tron S 55 quattro                    660.0                         4.5
# Audi e-tron S Sportback 55 quattro          615.0                         4.5
# Audi e-tron Sportback 50 quattro            615.0                         6.8
#
#                                     Maximum charging power  \
# Car full name
# Audi e-tron 50 quattro                                 150
# Audi e-tron 55 quattro                                 150
# Audi e-tron S 55 quattro                               150
# Audi e-tron S Sportback 55 quattro                     150
# Audi e-tron Sportback 50 quattro                       150
#
#                                     Mean Energy Consumption
# Car full name
# Audi e-tron 50 quattro                                23.80
# Audi e-tron 55 quattro                                24.45
# Audi e-tron S 55 quattro                              27.55
# Audi e-tron S Sportback 55 quattro                    27.20
# Audi e-tron Sportback 50 quattro                      23.30

# %%
#dropping off the unwanted columns
EV_Merged = EV_Merged.drop(labels=['Make', 'Minimal price (gross) [PLN]', 'Maximum speed [kph]_y', 'Acceleration 0-100 kph [s]'], axis = 1)
EV_Merged.head()
# Out:
#                                    Car Brand  Acceleration 0-100 kph[s]  \
# Car full name
# Audi e-tron 50 quattro                 Audi                         6.8
# Audi e-tron 55 quattro                 Audi                         5.7
# Audi e-tron S 55 quattro               Audi                         4.5
# Audi e-tron S Sportback 55 quattro     Audi                         4.5
# Audi e-tron Sportback 50 quattro       Audi                         6.8
#
#                                     Maximum speed [kph]_x  Range (WLTP) [km]  \
# Car full name
# Audi e-tron 50 quattro                                190                280
# Audi e-tron 55 quattro                                200                365
# Audi e-tron S 55 quattro                              210                320
# Audi e-tron S Sportback 55 quattro                    210                335
# Audi e-tron Sportback 50 quattro                      190                295
#
#                                     Battery efficiency [Wh/km]  \
# Car full name
# Audi e-tron 50 quattro                                     231
# Audi e-tron 55 quattro                                     237
# Audi e-tron S 55 quattro                                   270
# Audi e-tron S Sportback 55 quattro                         258
# Audi e-tron Sportback 50 quattro                           219
#
#                                     Rate of charge [km/h]  \
# Car full name
# Audi e-tron 50 quattro                              450.0
# Audi e-tron 55 quattro                              590.0
# Audi e-tron S 55 quattro                            510.0
# Audi e-tron S Sportback 55 quattro                  540.0
# Audi e-tron Sportback 50 quattro                    470.0
#
#                                    Rapid Charge Possible? PowerTrain  \
# Car full name
# Audi e-tron 50 quattro                                Yes        All
# Audi e-tron 55 quattro                                Yes        All
# Audi e-tron S 55 quattro                              Yes        All
# Audi e-tron S Sportback 55 quattro                    Yes        All
# Audi e-tron Sportback 50 quattro                      Yes        All
#
#                                       PlugType BodyStyle Segment  Seats  \
# Car full name
# Audi e-tron 50 quattro              Type 2 CCS       SUV       E      5
# Audi e-tron 55 quattro              Type 2 CCS       SUV       E      5
# Audi e-tron S 55 quattro            Type 2 CCS       SUV       E      5
# Audi e-tron S Sportback 55 quattro  Type 2 CCS       SUV       E      5
# Audi e-tron Sportback 50 quattro    Type 2 CCS       SUV       E      5
#
#                                     PriceEuro Segment Description  \
# Car full name
# Audi e-tron 50 quattro                  67358           Executive
# Audi e-tron 55 quattro                  79445           Executive
# Audi e-tron S 55 quattro                93800           Executive
# Audi e-tron S Sportback 55 quattro      96050           Executive
# Audi e-tron Sportback 50 quattro        69551           Executive
#
#                                     Engine power [KM]  Maximum torque [Nm]  \
# Car full name
# Audi e-tron 50 quattro                            313                  540
# Audi e-tron 55 quattro                            360                  664
# Audi e-tron S 55 quattro                          503                  973
# Audi e-tron S Sportback 55 quattro                503                  973
# Audi e-tron Sportback 50 quattro                  313                  540
#
#                                          Type of brakes  \
# Car full name
# Audi e-tron 50 quattro              disc (front + rear)
# Audi e-tron 55 quattro              disc (front + rear)
# Audi e-tron S 55 quattro            disc (front + rear)
# Audi e-tron S Sportback 55 quattro  disc (front + rear)
# Audi e-tron Sportback 50 quattro    disc (front + rear)
#
#                                     Battery capacity [kWh]  Wheelbase [cm]  \
# Car full name
# Audi e-tron 50 quattro                                71.0           292.8
# Audi e-tron 55 quattro                                95.0           292.8
# Audi e-tron S 55 quattro                              95.0           292.8
# Audi e-tron S Sportback 55 quattro                    95.0           292.8
# Audi e-tron Sportback 50 quattro                      71.0           292.8
#
#                                     Length [cm]  Width [cm]  Height [cm]  \
# Car full name
# Audi e-tron 50 quattro                    490.1       193.5        162.9
# Audi e-tron 55 quattro                    490.1       193.5        162.9
# Audi e-tron S 55 quattro                  490.2       197.6        162.9
# Audi e-tron S Sportback 55 quattro        490.2       197.6        161.5
# Audi e-tron Sportback 50 quattro          490.1       193.5        161.6
#
#                                     Minimal empty weight [kg]  \
# Car full name
# Audi e-tron 50 quattro                                   2445
# Audi e-tron 55 quattro                                   2565
# Audi e-tron S 55 quattro                                 2695
# Audi e-tron S Sportback 55 quattro                       2695
# Audi e-tron Sportback 50 quattro                         2445
#
#                                     Permissable gross weight [kg]  \
# Car full name
# Audi e-tron 50 quattro                                     3040.0
# Audi e-tron 55 quattro                                     3130.0
# Audi e-tron S 55 quattro                                   3130.0
# Audi e-tron S Sportback 55 quattro                         3130.0
# Audi e-tron Sportback 50 quattro                           3040.0
#
#                                     Maximum load capacity [kg]  \
# Car full name
# Audi e-tron 50 quattro                                   670.0
# Audi e-tron 55 quattro                                   640.0
# Audi e-tron S 55 quattro                                 565.0
# Audi e-tron S Sportback 55 quattro                       565.0
# Audi e-tron Sportback 50 quattro                         640.0
#
#                                     Tire size [in]  Boot capacity  \
# Car full name
# Audi e-tron 50 quattro                          19          660.0
# Audi e-tron 55 quattro                          19          660.0
# Audi e-tron S 55 quattro                        20          660.0
# Audi e-tron S Sportback 55 quattro              20          615.0
# Audi e-tron Sportback 50 quattro                19          615.0
#
#                                     Maximum charging power  \
# Car full name
# Audi e-tron 50 quattro                                 150
# Audi e-tron 55 quattro                                 150
# Audi e-tron S 55 quattro                               150
# Audi e-tron S Sportback 55 quattro                     150
# Audi e-tron Sportback 50 quattro                       150
#
#                                     Mean Energy Consumption
# Car full name
# Audi e-tron 50 quattro                                23.80
# Audi e-tron 55 quattro                                24.45
# Audi e-tron S 55 quattro                              27.55
# Audi e-tron S Sportback 55 quattro                    27.20
# Audi e-tron Sportback 50 quattro                      23.30

# %% [markdown]
# # **DATA VISUALIZATION**

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %% [markdown]
# There are some improtant things to consider before deciding to buy an electric car. Factors like the car's range, charging options, a family's needs and budget need to be evaluated properly. Through data visualization, we would analyse the data that we have and answer these questions.

# %% [markdown]
# a) **How far does one need to travel?**

# %% [markdown]
# Range is an important factor to consider before choosing an elelctric car. EVs offer a shorter range as compared to a diesel or petrol cars, so the range of the EV should be more than the average distance travelled by the user everyday.

# %%
px.scatter(EV_Merged,
          x='Car Brand',
          y='Range (WLTP) [km]',
          size='Range (WLTP) [km]', 
          color='Car Brand', 
          height = 800,
          title='Car Range')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="8c65937e-5a82-4c04-96a4-a4a0bd892812" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8c65937e-5a82-4c04-96a4-a4a0bd892812")) {                    Plotly.newPlot(                        "8c65937e-5a82-4c04-96a4-a4a0bd892812",                        [{"hovertemplate":"Car Brand=%{x}<br>Range (WLTP) [km]=%{marker.size}<extra></extra>","legendgroup":"Audi ","marker":{"color":"#636efa","size":[280,365,320,335,295,380],"sizemode":"area","sizeref":1.2875,"symbol":"circle"},"mode":"markers","name":"Audi ","orientation":"v","showlegend":true,"x":["Audi ","Audi ","Audi ","Audi ","Audi ","Audi "],"xaxis":"x","y":[280,365,320,335,295,380],"yaxis":"y","type":"scatter"},{"hovertemplate":"Car Brand=%{x}<br>Range (WLTP) [km]=%{marker.size}<extra></extra>","legendgroup":"BMW ","marker":{"color":"#EF553B","size":[235,230,360],"sizemode":"area","sizeref":1.2875,"symbol":"circle"},"mode":"markers","name":"BMW ","orientation":"v","showlegend":true,"x":["BMW ","BMW ","BMW "],"xaxis":"x","y":[235,230,360],"yaxis":"y","type":"scatter"},{"hovertemplate":"Car Brand=%{x}<br>Range (WLTP) [km]=%{marker.size}<extra></extra>","legendgroup":"DS ","marker":{"color":"#00cc96","size":[250],"sizemode":"area","sizeref":1.2875,"symbol":"circle"},"mode":"markers","name":"DS ","orientation":"v","showlegend":true,"x":["DS "],"xaxis":"x","y":[250],"yaxis":"y","type":"scatter"},{"hovertemplate":"Car Brand=%{x}<br>Range (WLTP) [km]=%{marker.size}<extra></extra>","legendgroup":"Honda ","marker":{"color":"#ab63fa","size":[170,170],"sizemode":"area","sizeref":1.2875,"symbol":"circle"},"mode":"markers","name":"Honda ","orientation":"v","showlegend":true,"x":["Honda ","Honda "],"xaxis":"x","y":[170,170],"yaxis":"y","type":"scatter"},{"hovertemplate":"Car Brand=%{x}<br>Range (WLTP) [km]=%{marker.size}<extra></extra>","legendgroup":"Hyundai ","marker":{"color":"#FFA15A","size":[250,255,400],"sizemode":"area","sizeref":1.2875,"symbol":"circle"},"mode":"markers","name":"Hyundai ","orientation":"v","showlegend":true,"x":["Hyundai ","Hyundai ","Hyundai "],"xaxis":"x","y":[250,255,400],"yaxis":"y","type":"scatter"},{"hovertemplate":"Car Brand=%{x}<br>Range (WLTP) [km]=%{marker.size}<extra></extra>","legendgroup":"Jaguar ","marker":{"color":"#19d3f3","size":[365],"sizemode":"area","sizeref":1.2875,"symbol":"circle"},"mode":"markers","name":"Jaguar ","orientation":"v","showlegend":true,"x":["Jaguar "],"xaxis":"x","y":[365],"yaxis":"y","type":"scatter"},{"hovertemplate":"Car Brand=%{x}<br>Range (WLTP) [km]=%{marker.size}<extra></extra>","legendgroup":"Kia ","marker":{"color":"#FF6692","size":[235,370,230,365],"sizemode":"area","sizeref":1.2875,"symbol":"circle"},"mode":"markers","name":"Kia ","orientation":"v","showlegend":true,"x":["Kia ","Kia ","Kia ","Kia "],"xaxis":"x","y":[235,370,230,365],"yaxis":"y","type":"scatter"},{"hovertemplate":"Car Brand=%{x}<br>Range (WLTP) [km]=%{marker.size}<extra></extra>","legendgroup":"Mazda ","marker":{"color":"#B6E880","size":[180],"sizemode":"area","sizeref":1.2875,"symbol":"circle"},"mode":"markers","name":"Mazda ","orientation":"v","showlegend":true,"x":["Mazda "],"xaxis":"x","y":[180],"yaxis":"y","type":"scatter"},{"hovertemplate":"Car Brand=%{x}<br>Range (WLTP) [km]=%{marker.size}<extra></extra>","legendgroup":"Mercedes ","marker":{"color":"#FF97FF","size":[370,330],"sizemode":"area","sizeref":1.2875,"symbol":"circle"},"mode":"markers","name":"Mercedes ","orientation":"v","showlegend":true,"x":["Mercedes ","Mercedes "],"xaxis":"x","y":[370,330],"yaxis":"y","type":"scatter"},{"hovertemplate":"Car Brand=%{x}<br>Range (WLTP) [km]=%{marker.size}<extra></extra>","legendgroup":"Mini ","marker":{"color":"#FECB52","size":[185],"sizemode":"area","sizeref":1. ...

# %% [markdown]
# There are many brands which have cars with small to medium range. Tesla has models with the highest range among all the brands.  If the car will be used for commuting to office and general runs around the city, one doesn't need a very high range. Whereas if it will be used to travel long distances or regular trips out of the city, a higher range car would be needed.  Depending on individual travel length requirements, a suitable brand can be chosen.

# %% [markdown]
# b) **What are the charging options in the car?**

# %% [markdown]
# Electric car charges come in different speeds : slow, fast and rapid. Many cars come with a charging cable that can be plugged into a normal socket at a house. But this is slow and depending on the car's range and size of the battery, it can take many hours and a fast charger can usually charge a car overnight. Whereas rapid charges are able to charge a car very fast and these charging stations can be found at many public places today. So, depending on the requirement, it is important to check if the car has rapid charging or not.

# %%
px.bar(EV_Merged, 
       x='Car Brand', 
       y='PriceEuro',
       color='Rapid Charge Possible?',
       hover_data=['Range (WLTP) [km]'],
       title='Is Rapid charge possible?')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="a3107191-8f41-42d7-902a-e99fc2552af8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a3107191-8f41-42d7-902a-e99fc2552af8")) {                    Plotly.newPlot(                        "a3107191-8f41-42d7-902a-e99fc2552af8",                        [{"alignmentgroup":"True","customdata":[[280],[365],[320],[335],[295],[380],[235],[230],[360],[250],[170],[170],[250],[255],[400],[365],[235],[370],[230],[365],[180],[370],[330],[185],[220],[325],[190],[275],[255],[250],[275],[365],[425],[390],[375],[315],[310],[195],[450],[435],[310],[515],[505],[450],[440],[340],[440],[420],[195]],"hovertemplate":"Rapid Charge Possible?=Yes<br>Car Brand=%{x}<br>PriceEuro=%{y}<br>Range (WLTP) [km]=%{customdata[0]}<extra></extra>","legendgroup":"Yes","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Yes","offsetgroup":"Yes","orientation":"v","showlegend":true,"textposition":"auto","x":["Audi ","Audi ","Audi ","Audi ","Audi ","Audi ","BMW ","BMW ","BMW ","DS ","Honda ","Honda ","Hyundai ","Hyundai ","Hyundai ","Jaguar ","Kia ","Kia ","Kia ","Kia ","Mazda ","Mercedes ","Mercedes ","Mini ","Nissan ","Nissan ","Nissan ","Opel ","Opel ","Peugeot ","Peugeot ","Porsche ","Porsche ","Porsche ","Porsche ","Renault ","Renault ","Skoda ","Tesla ","Tesla ","Tesla ","Tesla ","Tesla ","Tesla ","Tesla ","Volkswagen ","Volkswagen ","Volkswagen ","Volkswagen "],"xaxis":"x","y":[67358,79445,93800,96050,69551,81639,38017,41526,68040,37422,32997,35921,34459,33971,40795,75351,34400,38105,33133,36837,32646,69484,70631,31681,29234,37237,33246,29146,35000,34361,29682,102945,109302,148301,180781,31184,33133,24534,55480,61480,46380,79990,96990,85990,102990,35575,40936,45000,21421],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[95],[100]],"hovertemplate":"Rapid Charge Possible?=No<br>Car Brand=%{x}<br>PriceEuro=%{y}<br>Range (WLTP) [km]=%{customdata[0]}<extra></extra>","legendgroup":"No","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"No","offsetgroup":"No","orientation":"v","showlegend":true,"textposition":"auto","x":["Smart ","Smart "],"xaxis":"x","y":[22030,21387],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar": ...

# %% [markdown]
# It can be seen that all the brands except "Smart" have cars in which rapid charge is possible. This shows that all the brands have equipped their models with rapid charge option as this gives the user an ease of operation.

# %% [markdown]
# Apart from rapid charging, other factors to consider are the car's charging capacity and type of connector it has.

# %%
px.bar(EV_Merged, 
       x='Car Brand', 
       y='Maximum charging power',
       color='Maximum charging power', 
       title='DC Charging Power (kW)')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="e8213a19-2651-4968-a2dc-837ddcfba87e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e8213a19-2651-4968-a2dc-837ddcfba87e")) {                    Plotly.newPlot(                        "e8213a19-2651-4968-a2dc-837ddcfba87e",                        [{"alignmentgroup":"True","hovertemplate":"Car Brand=%{x}<br>Maximum charging power=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[150,150,150,150,150,150,50,50,150,100,100,100,100,100,100,100,100,100,100,100,37,110,110,50,50,100,50,100,100,100,100,225,270,270,270,50,50,40,22,22,150,150,150,150,150,150,150,100,125,125,40],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Audi ","Audi ","Audi ","Audi ","Audi ","Audi ","BMW ","BMW ","BMW ","DS ","Honda ","Honda ","Hyundai ","Hyundai ","Hyundai ","Jaguar ","Kia ","Kia ","Kia ","Kia ","Mazda ","Mercedes ","Mercedes ","Mini ","Nissan ","Nissan ","Nissan ","Opel ","Opel ","Peugeot ","Peugeot ","Porsche ","Porsche ","Porsche ","Porsche ","Renault ","Renault ","Skoda ","Smart ","Smart ","Tesla ","Tesla ","Tesla ","Tesla ","Tesla ","Tesla ","Tesla ","Volkswagen ","Volkswagen ","Volkswagen ","Volkswagen "],"xaxis":"x","y":[150,150,150,150,150,150,50,50,150,100,100,100,100,100,100,100,100,100,100,100,37,110,110,50,50,100,50,100,100,100,100,225,270,270,270,50,50,40,22,22,150,150,150,150,150,150,150,100,125,125,40],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.55 ...

# %% [markdown]
# The above graph analyzes charging capcity of the vehicles, and it can be seen that Porsche make the fastest charging cars at 270kW, followed by Tesla and Audi cars with charging speed of 150kW.

# %%
px.pie(EV_Merged, names='PlugType',  
       title='Charging Connector Type')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="8761419b-414e-442c-b713-ba27d0cf9600" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8761419b-414e-442c-b713-ba27d0cf9600")) {                    Plotly.newPlot(                        "8761419b-414e-442c-b713-ba27d0cf9600",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"PlugType=%{label}<extra></extra>","labels":["Type 2 CCS","Type 2 CCS","Type 2 CCS","Type 2 CCS","Type 2 CCS","Type 2 CCS","Type 2 CCS","Type 2 CCS","Type 2 CCS","Type 2 CCS","Type 2 CCS","Type 2 CCS","Type 2 CCS","Type 2 CCS","Type 2 CCS","Type 2 CCS","Type 2 CCS","Type 2 CCS","Type 2 CCS","Type 2 CCS","Type 2 CCS","Type 2 CCS","Type 2 CCS","Type 2 CCS","Type 2 CHAdeMO","Type 2 CHAdeMO","Type 1 CHAdeMO","Type 2 CCS","Type 2 CCS","Type 2 CCS","Type 2 CCS","Type 2 CCS","Type 2 CCS","Type 2 CCS","Type 2 CCS","Type 2 CCS","Type 2 CCS","Type 2 CCS","Type 2","Type 2","Type 2 CCS","Type 2 CCS","Type 2 CCS","Type 2","Type 2","Type 2","Type 2","Type 2 CCS","Type 2 CCS","Type 2 CCS","Type 2 CCS"],"legendgroup":"","name":"","showlegend":true,"type":"pie"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555 ...

# %% [markdown]
# Type 2 CCS is the most common type of connector port installed in the cars.

# %% [markdown]
# c) **What will be the car used for?**

# %% [markdown]
# It will be important to consider if the car suits its owner's personal preference or family needs. Some factors to evaluate are size of the car and number of seats.

# %%
px.bar(EV_Merged, 
       x='Car Brand', 
       y='Range (WLTP) [km]',
       color='Segment Description',
       hover_name='Seats',
       title='Car by Segments')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="8916b383-f162-4be5-92f8-fbaf55c0430b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8916b383-f162-4be5-92f8-fbaf55c0430b")) {                    Plotly.newPlot(                        "8916b383-f162-4be5-92f8-fbaf55c0430b",                        [{"alignmentgroup":"True","hovertemplate":"<b>%{hovertext}</b><br><br>Segment Description=Executive<br>Car Brand=%{x}<br>Range (WLTP) [km]=%{y}<extra></extra>","hovertext":[5.0,5.0,5.0,5.0,5.0,5.0,5.0],"legendgroup":"Executive","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Executive","offsetgroup":"Executive","orientation":"v","showlegend":true,"textposition":"auto","x":["Audi ","Audi ","Audi ","Audi ","Audi ","Audi ","Jaguar "],"xaxis":"x","y":[280,365,320,335,295,380,365],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"<b>%{hovertext}</b><br><br>Segment Description=Supermini<br>Car Brand=%{x}<br>Range (WLTP) [km]=%{y}<extra></extra>","hovertext":[4.0,4.0,5.0,4.0,4.0,5.0,5.0,5.0,5.0,4.0,5.0,5.0,5.0,5.0,5.0,5.0],"legendgroup":"Supermini","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Supermini","offsetgroup":"Supermini","orientation":"v","showlegend":true,"textposition":"auto","x":["BMW ","BMW ","DS ","Honda ","Honda ","Hyundai ","Hyundai ","Kia ","Kia ","Mini ","Opel ","Opel ","Peugeot ","Peugeot ","Renault ","Renault "],"xaxis":"x","y":[235,230,250,170,170,255,400,230,365,185,275,255,250,275,315,310],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"<b>%{hovertext}</b><br><br>Segment Description=Large Family<br>Car Brand=%{x}<br>Range (WLTP) [km]=%{y}<extra></extra>","hovertext":[5.0,5.0,5.0,5.0,5.0],"legendgroup":"Large Family","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Large Family","offsetgroup":"Large Family","orientation":"v","showlegend":true,"textposition":"auto","x":["BMW ","Mercedes ","Tesla ","Tesla ","Tesla "],"xaxis":"x","y":[360,370,450,435,310],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"<b>%{hovertext}</b><br><br>Segment Description=Small Family<br>Car Brand=%{x}<br>Range (WLTP) [km]=%{y}<extra></extra>","hovertext":[5.0,5.0,5.0,5.0,5.0,5.0,5.0,4.0,5.0],"legendgroup":"Small Family","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Small Family","offsetgroup":"Small Family","orientation":"v","showlegend":true,"textposition":"auto","x":["Hyundai ","Kia ","Kia ","Mazda ","Nissan ","Nissan ","Volkswagen ","Volkswagen ","Volkswagen "],"xaxis":"x","y":[250,235,370,180,220,325,340,440,420],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"<b>%{hovertext}</b><br><br>Segment Description=Commercial<br>Car Brand=%{x}<br>Range (WLTP) [km]=%{y}<extra></extra>","hovertext":[7.0,7.0],"legendgroup":"Commercial","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Commercial","offsetgroup":"Commercial","orientation":"v","showlegend":true,"textposition":"auto","x":["Mercedes ","Nissan "],"xaxis":"x","y":[330,190],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"<b>%{hovertext}</b><br><br>Segment Description=Luxury<br>Car Brand=%{x}<br>Range (WLTP) [km]=%{y}<extra></extra>","hovertext":[4.0,4.0,4.0,4.0,5.0,5.0,7.0,7.0],"legendgroup":"Luxury","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Luxury","offsetgroup":"Luxury","orientation":"v","showlegend":true,"textposition":"auto","x":["Porsche ","Porsche ","Porsche ","Porsche ","Tesla ","Tesla ","Tesla ","Tesla "],"xaxis":"x","y":[365,425,390,375,515,505,450,440],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"<b>%{hovertext}</b><br><br>Segment Description=Mini<br>Car Brand=%{x}<br>Range (WLTP) [km]=%{y}<extra></extra>","hovertext":[4.0,4.0,2.0,4.0],"legendgr ...

# %% [markdown]
# Majority of the brands produce Supermini cars, which limits the options for customers looking to buy a vehicle for a family. Some brands have no diversification in segments and produce only one type of vehicle, for example Porsche makes only Luxury cars and Audi produces Executive cars. A customer wanting to buy a small family car has very few brands to choose from, even less so if it is for a large family. It is to be noted that only Nissan and Mercedes produce commercial vehicles while Tesla has both luxury and large family type cars.

# %% [markdown]
# d) **Does the car fit budget?**

# %%
px.bar(EV_Merged, 
       x='Car Brand', 
       y='PriceEuro',
       color='PriceEuro',
       title='Car Price')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="446a8064-2992-471b-97b2-5b5fff82e792" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("446a8064-2992-471b-97b2-5b5fff82e792")) {                    Plotly.newPlot(                        "446a8064-2992-471b-97b2-5b5fff82e792",                        [{"alignmentgroup":"True","hovertemplate":"Car Brand=%{x}<br>PriceEuro=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[67358,79445,93800,96050,69551,81639,38017,41526,68040,37422,32997,35921,34459,33971,40795,75351,34400,38105,33133,36837,32646,69484,70631,31681,29234,37237,33246,29146,35000,34361,29682,102945,109302,148301,180781,31184,33133,24534,22030,21387,55480,61480,46380,79990,96990,85990,102990,35575,40936,45000,21421],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Audi ","Audi ","Audi ","Audi ","Audi ","Audi ","BMW ","BMW ","BMW ","DS ","Honda ","Honda ","Hyundai ","Hyundai ","Hyundai ","Jaguar ","Kia ","Kia ","Kia ","Kia ","Mazda ","Mercedes ","Mercedes ","Mini ","Nissan ","Nissan ","Nissan ","Opel ","Opel ","Peugeot ","Peugeot ","Porsche ","Porsche ","Porsche ","Porsche ","Renault ","Renault ","Skoda ","Smart ","Smart ","Tesla ","Tesla ","Tesla ","Tesla ","Tesla ","Tesla ","Tesla ","Volkswagen ","Volkswagen ","Volkswagen ","Volkswagen "],"xaxis":"x","y":[67358,79445,93800,96050,69551,81639,38017,41526,68040,37422,32997,35921,34459,33971,40795,75351,34400,38105,33133,36837,32646,69484,70631,31681,29234,37237,33246,29146,35000,34361,29682,102945,109302,148301,180781,31184,33133,24534,22030,21387,55480,61480,46380,79990,96990,85990,102990,35575,40936,45000,21421],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"hist ...

# %% [markdown]
# Porsche cars are priced on the higher range, which can be directly related to the fact that the brand makes only luxury cars with a high charging capacity. However, there are many brands which have models that can fit a lower budget.

# %% [markdown]
# A graph can be mapped for price and range to check for cars which can give a combination of desired range and fit the budget.

# %%
px.scatter(EV_Merged,
          x='Car Brand',
          y='PriceEuro',
          size='Range (WLTP) [km]', 
          color='Car Brand', 
          hover_name = 'Battery capacity [kWh]',
          height = 800,
          title='Price vs Range')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="8901f7b4-6fa8-4558-b1bd-4c44bfabda4d" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8901f7b4-6fa8-4558-b1bd-4c44bfabda4d")) {                    Plotly.newPlot(                        "8901f7b4-6fa8-4558-b1bd-4c44bfabda4d",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>Car Brand=%{x}<br>PriceEuro=%{y}<br>Range (WLTP) [km]=%{marker.size}<extra></extra>","hovertext":[71.0,95.0,95.0,95.0,71.0,95.0],"legendgroup":"Audi ","marker":{"color":"#636efa","size":[280,365,320,335,295,380],"sizemode":"area","sizeref":1.2875,"symbol":"circle"},"mode":"markers","name":"Audi ","orientation":"v","showlegend":true,"x":["Audi ","Audi ","Audi ","Audi ","Audi ","Audi "],"xaxis":"x","y":[67358,79445,93800,96050,69551,81639],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>Car Brand=%{x}<br>PriceEuro=%{y}<br>Range (WLTP) [km]=%{marker.size}<extra></extra>","hovertext":[42.2,42.2,80.0],"legendgroup":"BMW ","marker":{"color":"#EF553B","size":[235,230,360],"sizemode":"area","sizeref":1.2875,"symbol":"circle"},"mode":"markers","name":"BMW ","orientation":"v","showlegend":true,"x":["BMW ","BMW ","BMW "],"xaxis":"x","y":[38017,41526,68040],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>Car Brand=%{x}<br>PriceEuro=%{y}<br>Range (WLTP) [km]=%{marker.size}<extra></extra>","hovertext":[50.0],"legendgroup":"DS ","marker":{"color":"#00cc96","size":[250],"sizemode":"area","sizeref":1.2875,"symbol":"circle"},"mode":"markers","name":"DS ","orientation":"v","showlegend":true,"x":["DS "],"xaxis":"x","y":[37422],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>Car Brand=%{x}<br>PriceEuro=%{y}<br>Range (WLTP) [km]=%{marker.size}<extra></extra>","hovertext":[35.5,35.5],"legendgroup":"Honda ","marker":{"color":"#ab63fa","size":[170,170],"sizemode":"area","sizeref":1.2875,"symbol":"circle"},"mode":"markers","name":"Honda ","orientation":"v","showlegend":true,"x":["Honda ","Honda "],"xaxis":"x","y":[32997,35921],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>Car Brand=%{x}<br>PriceEuro=%{y}<br>Range (WLTP) [km]=%{marker.size}<extra></extra>","hovertext":[38.3,39.2,64.0],"legendgroup":"Hyundai ","marker":{"color":"#FFA15A","size":[250,255,400],"sizemode":"area","sizeref":1.2875,"symbol":"circle"},"mode":"markers","name":"Hyundai ","orientation":"v","showlegend":true,"x":["Hyundai ","Hyundai ","Hyundai "],"xaxis":"x","y":[34459,33971,40795],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>Car Brand=%{x}<br>PriceEuro=%{y}<br>Range (WLTP) [km]=%{marker.size}<extra></extra>","hovertext":[90.0],"legendgroup":"Jaguar ","marker":{"color":"#19d3f3","size":[365],"sizemode":"area","sizeref":1.2875,"symbol":"circle"},"mode":"markers","name":"Jaguar ","orientation":"v","showlegend":true,"x":["Jaguar "],"xaxis":"x","y":[75351],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>Car Brand=%{x}<br>PriceEuro=%{y}<br>Range (WLTP) [km]=%{marker.size}<extra></extra>","hovertext":[39.2,64.0,39.2,64.0],"legendgroup":"Kia ","marker":{"color":"#FF6692","size":[235,370,230,365],"sizemode":"area","sizeref":1.2875,"symbol":"circle"},"mode":"markers","name":"Kia ","orientation":"v","showlegend":true,"x":["Kia ","Kia ","Kia ","Kia "],"xaxis":"x","y":[34400,38105,33133,36837],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>Car Brand=%{x}<br>PriceEuro=%{y}<br>Range (WLTP) [km]=%{marker.size}<extra></extra>","hovertext":[35.5],"legendgroup":"Mazda ","marker":{"color":"#B6E880","size":[180],"sizemode":"area","sizeref":1.2875,"symbol":"circle"},"mode":"markers","name":"Mazda ","orientation":"v","showlegend":t ...

# %% [markdown]
# As seen above, Porsche has cars in the higher price range, but it does not equate to longer range or better battery capacity. There are many options from brands like Tesla, Audi, Jaguar which have a lower price and have better range as well as battery capacity between 90-100kWh.

# %% [markdown]
# e) **Is there a correlation between certain features?**

# %% [markdown]
# There are certain other features, like acceleration and speed, that are important when considering an EV. A Heatmap can be plotted to check if there is a correlation between these features.

# %%
cars_corr = EV_Merged[['Maximum charging power', 'Range (WLTP) [km]', 'Battery efficiency [Wh/km]', 'Maximum speed [kph]_x', 'Rate of charge [km/h]', 'Maximum torque [Nm]', 'Battery capacity [kWh]', 'Engine power [KM]']]
cars_corr.head()
# Out:
#                                     Maximum charging power  Range (WLTP) [km]  \
# Car full name
# Audi e-tron 50 quattro                                 150                280
# Audi e-tron 55 quattro                                 150                365
# Audi e-tron S 55 quattro                               150                320
# Audi e-tron S Sportback 55 quattro                     150                335
# Audi e-tron Sportback 50 quattro                       150                295
#
#                                     Battery efficiency [Wh/km]  \
# Car full name
# Audi e-tron 50 quattro                                     231
# Audi e-tron 55 quattro                                     237
# Audi e-tron S 55 quattro                                   270
# Audi e-tron S Sportback 55 quattro                         258
# Audi e-tron Sportback 50 quattro                           219
#
#                                     Maximum speed [kph]_x  \
# Car full name
# Audi e-tron 50 quattro                                190
# Audi e-tron 55 quattro                                200
# Audi e-tron S 55 quattro                              210
# Audi e-tron S Sportback 55 quattro                    210
# Audi e-tron Sportback 50 quattro                      190
#
#                                     Rate of charge [km/h]  \
# Car full name
# Audi e-tron 50 quattro                              450.0
# Audi e-tron 55 quattro                              590.0
# Audi e-tron S 55 quattro                            510.0
# Audi e-tron S Sportback 55 quattro                  540.0
# Audi e-tron Sportback 50 quattro                    470.0
#
#                                     Maximum torque [Nm]  \
# Car full name
# Audi e-tron 50 quattro                              540
# Audi e-tron 55 quattro                              664
# Audi e-tron S 55 quattro                            973
# Audi e-tron S Sportback 55 quattro                  973
# Audi e-tron Sportback 50 quattro                    540
#
#                                     Battery capacity [kWh]  Engine power [KM]
# Car full name
# Audi e-tron 50 quattro                                71.0                313
# Audi e-tron 55 quattro                                95.0                360
# Audi e-tron S 55 quattro                              95.0                503
# Audi e-tron S Sportback 55 quattro                    95.0                503
# Audi e-tron Sportback 50 quattro                      71.0                313

# %%
plt.figure(figsize=(8,8))
sns.heatmap((cars_corr).corr(), annot=True, cmap='coolwarm')

# %% [markdown]
# It can be seen that there is a strong coorelation between Engine power, Maximum speed, Torque and Battery capacity. Battery efficiency and range are correlated with battery capacity.

# %% [markdown]
# EV's produce maximum torque instantly from standstill, so acceleration can bemapped with maximum speed to analyze if they are correlated.

# %%
px.scatter(EV_Merged, x = 'Car Brand', 
           y = 'Acceleration 0-100 kph[s]',
           color = 'Maximum speed [kph]_x')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="7397ab01-a0fd-466b-a70b-ef5566fda558" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7397ab01-a0fd-466b-a70b-ef5566fda558")) {                    Plotly.newPlot(                        "7397ab01-a0fd-466b-a70b-ef5566fda558",                        [{"hovertemplate":"Car Brand=%{x}<br>Acceleration 0-100 kph[s]=%{y}<br>Maximum speed [kph]_x=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[190,200,210,210,190,200,150,160,180,150,145,145,165,155,167,200,155,167,157,167,150,180,140,150,144,157,123,150,150,150,150,250,250,260,260,135,140,130,130,130,233,261,225,250,261,250,250,160,160,160,130],"coloraxis":"coloraxis","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":["Audi ","Audi ","Audi ","Audi ","Audi ","Audi ","BMW ","BMW ","BMW ","DS ","Honda ","Honda ","Hyundai ","Hyundai ","Hyundai ","Jaguar ","Kia ","Kia ","Kia ","Kia ","Mazda ","Mercedes ","Mercedes ","Mini ","Nissan ","Nissan ","Nissan ","Opel ","Opel ","Peugeot ","Peugeot ","Porsche ","Porsche ","Porsche ","Porsche ","Renault ","Renault ","Skoda ","Smart ","Smart ","Tesla ","Tesla ","Tesla ","Tesla ","Tesla ","Tesla ","Tesla ","Volkswagen ","Volkswagen ","Volkswagen ","Volkswagen "],"xaxis":"x","y":[6.8,5.7,4.5,4.5,6.8,5.7,7.3,6.9,6.8,8.7,9.5,8.3,9.7,9.9,7.9,4.8,9.8,7.8,9.9,7.9,9.0,5.1,10.0,7.3,7.9,7.3,14.0,8.1,8.5,8.5,8.1,4.0,4.0,3.2,2.8,11.4,9.5,12.3,12.7,11.6,4.6,3.4,5.6,3.8,2.5,4.6,2.8,7.3,7.9,7.5,11.9],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444 ...

# %% [markdown]
# It can be seen that Porsche and Tesla have cars with maximum speed. And there is no correlation between acceleration and maximum speed. So if a person is looking for high speed in their car, Porsche and Tesla will be a better option.

# %% [markdown]
# # **CONCLUSION**

# %% [markdown]
# All the major car manufactureres have launched different models of electric vehicles in the market. An EVs ability to rapid charge is an important feature, and almost all the cars have this option available these days. Type 2 CCS is the most common type of connector installed and is used for rapid charging. Range of the EVs varies from 95km (Smart) to 515km (Tesla). Depending on vehicle's average usage, one can choose between the many options that are available.

# %% [markdown]
# Porsche makes only luxury cars which are high priced and have faster charging power. However, a higher price does not equate to a higher range. Porsche models have range between 365-425km whereas Tesla has a a model with range of 515km at much lesser price. Battery capacity is also an important factor to consider while buying an EV. Tesla, Audi and Jaguar lower priced cars with good range and battery capacity between 90-100kWh. Most of the models are for supermini cars, but one can find cars suited for a small and large families as well.

# %% [markdown]
# Overall, it is very clear that electric vehicles are the future of cars. The sector is seeing constant changes with better and imrpoved models being launched by manufacturers. With a variety of models and specifications available  there is something to suit for everybody's needs. The parameters discussed above can provide a basis for anyone interested in exploring and choosing an EV for themselves and their family.

# %% [markdown]
# **Additional Information**

# %% [markdown]
# A separate dataset has been used to provide charge point locations in the UK. The charging points have been shown in a map

# %% [markdown]
# Please enter your mapbox API key text file below:

# %%
## First run this cell to "import" image into the notebook's space
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7be2e8bc-a98d-41e9-bed3-c81d3b4b0f36" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7be2e8bc-a98d-41e9-bed3-c81d3b4b0f36">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving mapbox.txt to mapbox (2).txt

# %%
# Importing the necessary modules
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
# Importing the token
px.set_mapbox_access_token(open("/content/mapbox.txt").read())

# %%
charge_points = pd.read_csv('https://github.com/JoLRThomson/CMM202JoT/blob/main/national-charge-point-registry.csv?raw=1')
charge_points_summ = charge_points[['chargeDeviceID', 'name', 'town', 'county', 'latitude', 'longitude']]
charge_points_summ.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning:
#
# Columns (5,10,11,16,17,18,19,44,51,54,56,57,58,59,60,61,62,63,64,65,66,67,68,69,79,90,101,112,115,119,122,123,126,130,133,134,137,141,144,148,152,155) have mixed types.Specify dtype option on import or set low_memory=False.
#                      chargeDeviceID                                      name  \
# 0  9c8661befae6dbcd08304dbf4dcaf0db    Little Victoria St Car Park - Socket 2
# 1  52b738b303d90a884137546353e09ebb  Little Donegall Street, Belfast (Socket
# 2  b58ac8403eb9cf17fae1dcd16df71fde         Cromac Street Car Park (Socket 2)
# 3  fd8c07a31f8a85910ad8476f5f7efb27  Hope Street Car Park, Belfast (Socket 2)
# 4  f507783927f2ec2737ba40afbd17efb5       Adelaide Street, Belfast (Socket 2)
#
#       town         county   latitude  longitude
# 0  Belfast  County Antrim  54.592703  -5.933430
# 1  Belfast  County Antrim  54.604646  -5.931866
# 2  Belfast  County Antrim  54.594109  -5.924292
# 3  Belfast  County Antrim  54.593365  -5.935574
# 4  Belfast  County Antrim  54.594342  -5.928256

# %%
print(charge_points_summ.dtypes)
# Out:
# chargeDeviceID     object
# name               object
# town               object
# county             object
# latitude          float64
# longitude         float64
# dtype: object

# %%
fig = px.scatter_mapbox(charge_points_summ, lat="latitude", lon="longitude", 
                        hover_name='town',
                        hover_data=['name'],
                        title='Charging Points across UK',
                  color_continuous_scale=px.colors.cyclical.IceFire, size_max=15, zoom=10)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="6d6c2301-07ce-491e-bc4a-e9de8b455cb0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6d6c2301-07ce-491e-bc4a-e9de8b455cb0")) {                    Plotly.newPlot(                        "6d6c2301-07ce-491e-bc4a-e9de8b455cb0",                        [{"customdata":[["Little Victoria St Car Park - Socket 2"],["Little Donegall Street, Belfast (Socket "],["Cromac Street Car Park (Socket 2)"],["Hope Street Car Park, Belfast (Socket 2)"],["Adelaide Street, Belfast (Socket 2)"],["Lower Crescent, Belfast (Socket 2)"],["Central Station, Belfast (Socket 2)"],["Cairns Hill Park and Ride, Belfast (Sock"],["Linenhall Street, Armagh DRD Car Park (S"],["Palace Demense (Socket 2)"],["Donnellys Garage, 57 Moy Road, Dungannon"],["Fiveways Shops & Service Station Newry"],["Bagenal's Castle, Newry (Socket 2)"],["Bridge Street Car Park, Newry (Socket 2)"],["Basin Walk Car Park, Newry (Socket 2)"],["Canal Court Merchants Quay, Newry (Socke"],["Hill Street, Newry (Socket 2)"],["Monaghan Street, Newry (Socket 2)"],["Newry Train station (Socket 2)"],["Glenshane Tourist Services Ltd"],["Victoria Market, L'Derry (Socket 2)"],["Bishop Street car park, L'Derry (Socket "],["Railway Yard, L'Derry (Socket 2)"],["Strand Road, L'derry (Socket 2)"],["Carlisle Road, L'Derry (Socket 2)"],["The Diamond, L'Derry (Socket 2)"],["Templemore Leisure Centre, L'Derry (Sock"],["Down/Market/Cross Street - Socket 2"],["Eden Street, Enniskillen (Socket 2)"],["Quay Lane North, Enniskillen (Socket 2)"],["Wellington Street, Enniskillen (Socket 2"],["Queen St, Enniskillen (Socket 2)"],["Cross Street Car Park"],["Main Street, Irvinestown (Socket 2)"],["Main Street, Belleek (Socket 2)"],["Narrow Gauge Road, Larne (Socket 2)"],["Agnew Street, Larne (Socket 2)"],["Riverdale, Larne (Socket 2)"],["Havelock Place, Carnlough, Larne (Socket"],["South West College, Cookstown (Socket 2)"],["Alex F Noble & Son"],["Ancaster Nissan Dealership"],["Ashton Hayes"],["Beadles Nissan Ltd "],["Benfield Motors"],["Circus Road"],["Covent Garden Car Park"],["FJ Chalke Nissan Dealership"],["Fred Coupe Nissan Dealership"],["G24 Innovations"],["Galson Trust"],["Gatwick North Terminal"],["Gatwick South Terminal"],["Glyn Hopkin Nissan Dealership"],["Glyn Hopkin Nissan Dealership"],["Hitachi Newbury - A"],["Hitachi Trowbridge - A"],["HMP Belmarsh"],["HMP Belmarsh"],["JFE Nissan Dealership"],["Lightcliffe Nissan Dealership"],["Lincolns Inn Fields "],["London Road Car Park"],["Lupus Street"],["M&S Food Eco Store"],["Motorline Nissan Dealership"],["Nissan Blackshaws"],["Nissan Holdcroft Stoke-On-Trent"],["Nissan Motors GB Ltd 1"],["Nissan Motors GB Ltd 2"],["Nissan Wessex Bristol"],["Nissan WLMG Mill Hill"],["Nissan WLMG Reading"],["Oaklands College"],["Orkney Islands Council"],["Royal Military Academy"],["Royal Military Academy"],["Royal Military Academy"],["Royal Military Academy"],["Sainsburys Bishop Auckland"],["Sainsburys Colne"],["Sainsburys Dursley"],["Sainsburys Westhoughton"],["Saint Peters Car Park"],["Simon Bales Peugeot"],["Smiths Motor Group Nissan Dealership"],["Tesco Head Office (Cheshunt)"],["Tesco Head Office (Welwyn)"],["Tesco Kennington"],["Tesco Kensington"],["Wessex Garages Cardiff "],["West Way Aldershot"],["West Way Oxford "],["West Way Southampton "],["West Way Stockport "],["Westover Nissan "],["Yeomans Nissan Dealership"],["Portrush Service Station, Bushmills Rd"],["MK1"],["MK2"],["MK3"],["Next Retail (MK4)"],["MK5"],["MK6"],["MK7"],["MK8"],["Iceland Foods"],["MK10"],["Virgin Money (MK11)"],["MK12"],["Travelodge Hotel"],["Silverstone Innovation Centre"],["MK15"],["MK16"],["MK17"],["MK18"],["MK19"],["Easton Street Car Park"],["Silverstone Circuit (Car Park 49)"],["MK22"],["MK23"],["Mossley West  ...
